# %%
import pandas as pd
df = pd.read_csv("Downloads\\Indonesian_volcanoes.csv")
df
# Out:
#     Type        Volcano  Latitude   Longitude    Region
# 0      A  Seulawah Agam  5.447028   95.656664  Sumatera
# 1      A     Peut Sague  4.902609   96.288863  Sumatera
# 2      A   Burni Telong  4.766995   96.824227  Sumatera
# 3      A       Sinabung  3.169905   98.391041  Sumatera
# 4      A   Sorik Marapi  0.685781   99.536326  Sumatera
# ..   ...            ...       ...         ...       ...
# 122    C     Batu kolok  1.161703  124.764001  Sulawesi
# 123    C        Tempang  1.171547  124.843595  Sulawesi
# 124    C        Tampusu  1.265879  124.852164  Sulawesi
# 125    C      Lahendong  1.275056  124.829248  Sulawesi
# 126    C     Sarongsong  1.283968  124.821566  Sulawesi
#
# [127 rows x 5 columns]

# %%
# pip install folium

# %%
import folium

loc_center = [df['Latitude'].mean(), df['Longitude'].mean()]

# %%
map1 = folium.Map(location = loc_center, tiles='Openstreetmap', zoom_start = 5, control_scale=True)
for index, loc in df.iterrows():
    folium.CircleMarker([loc['Latitude'], loc['Longitude']],     radius=2, weight=5, popup=loc['Volcano']).add_to(map1)
folium.LayerControl().add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map2 = folium.Map(location = loc_center, tiles='Stamen Terrain', zoom_start = 5, control_scale=True)
for index, loc in df.iterrows():
    if loc['Type']=='A':
        color = 'red'
    elif loc['Type']=='B':
        color = "yellow"
    elif loc['Type']=='C':
        color = 'green'
    else:
        color = 'black'
    folium.RegularPolygonMarker([loc['Latitude'], loc['Longitude']], popup = loc['Volcano'], fill_color=color, number_of_sides=3, radius=6, rotation=30).add_to(map2)

folium.LayerControl().add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('D:\\Kuliah\\Dataset\\DataPenanaman_Blitar2.csv')
df
# Out:
#        Komoditas       Suhu  Curah Hujan  Kelembapan        ph  Jenis Tanah
# 0   Bawang Merah  27.893405   215.604282   54.731703  6.415515            1
# 1   Bawang Merah  27.446650   231.878971   52.489873  5.617661            1
# 2   Bawang Merah  30.748190   213.294814   51.380207  5.903834            1
# 3   Bawang Merah  26.758127   201.018163   50.611648  5.946495            1
# 4   Bawang Merah  30.434843   220.036048   50.640560  6.370265            1
# ..           ...        ...          ...         ...       ...          ...
# 94         Kubis  15.319932   192.967142   83.406066  6.831725            2
# 95         Kubis  17.511685   196.995720   84.603797  6.790985            2
# 96         Kubis  18.547372   199.141136   80.929976  6.259514            2
# 97         Kubis  16.457992   200.037249   82.458141  6.042392            2
# 98         Kubis  17.555224   185.639480   81.334653  6.393462            2
#
# [99 rows x 6 columns]

# %%
# random_decimal_array = np.random.uniform(0, 10, 5)  # Generate 5 random numbers
# print(random_decimal_array)

data = {
    'Kopiph': np.random.uniform(5.6, 6.5, 100),
    'Feb': np.random.uniform(5.5, 6.5, 100),
    'Mar': np.random.uniform(6, 7, 100),
    'Apr': np.random.uniform(6, 7, 100),
    'May': np.random.uniform(5.5, 7, 100),
    'Jun' : np.random.uniform(5.5, 6, 100),
    'Jul' : np.random.uniform(6, 7, 100),
    'Aug' : np.random.uniform(6, 7, 100),
    'Sep' : np.random.uniform(6, 7, 100),
    'Oct' : np.random.uniform(6, 7, 100),
    'Nov' : np.random.uniform(6, 7, 100),
    'Dec' : np.random.uniform(6, 7, 100)
}

df2 = pd.DataFrame(data)
df2
# Out:
#       bawang  cabbesar     melon  cabrawit     tomat   kentang     kubis
# 0   6.440599  6.404122  6.714983  6.282021  5.842636  5.830953  6.942145
# 1   5.775009  6.331420  6.680478  6.025948  6.166304  5.588166  6.579477
# 2   6.005796  5.919015  6.859712  6.162385  6.543812  5.803721  6.580564
# 3   5.671608  5.647031  6.622405  6.051974  5.623382  5.863484  6.795385
# 4   5.605439  6.206675  6.125761  6.569956  6.708679  5.727875  6.675883
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  5.667029  6.072129  6.827501  6.416576  6.102058  5.809065  6.151548
# 96  6.155726  5.576144  6.558368  6.562610  5.975560  5.623902  6.473595
# 97  6.017074  5.866342  6.687106  6.449184  5.567623  5.824853  6.051907
# 98  6.177975  5.696998  6.268125  6.775470  6.152137  5.739158  6.573941
# 99  6.418389  6.016827  6.321818  6.938230  6.470143  5.912724  6.847891
#
# [100 rows x 7 columns]

# %%
data = {
    
    'jagungsuhu' : np.random.uniform(28, 33, 100),
    'jagunghujan' : np.random.uniform(100, 160, 100),
    'jagunglembab' : np.random.uniform(80, 90, 100),
    'pisangph' : np.random.uniform(6.5, 7.5, 100),
    'pisangsuhu' : np.random.uniform(22, 28, 100),
    'pisanghujan' : np.random.uniform(140, 180, 100),
    'pisanglembab' : np.random.uniform(60, 65, 100),
    'manggaph' : np.random.uniform(5.5, 7.5, 100),
    'manggasuhu' : np.random.uniform(26, 32, 100),
    'manggahujan' : np.random.uniform(130, 160, 100),
    'manggalembab' : np.random.uniform(85, 90, 100),
    'anggurph' : np.random.uniform(6, 7, 100),
    'anggursuhu' : np.random.uniform(26, 31, 100),
    'anggurhujan' : np.random.uniform(66, 100, 100),
    'anggurlembab' : np.random.uniform(75, 80, 100),
    'semangkaph' : np.random.uniform(6, 7, 100),
    'semangkasuhu' : np.random.uniform(22, 27, 100),
    'semangkahujan' : np.random.uniform(40, 50, 100),
    'semangkalembab' : np.random.uniform(65, 75, 100),
    'apelph' : np.random.uniform(6, 7, 100),
    'apelsuhu' : np.random.uniform(24, 28, 100),
    'apelhujan' : np.random.uniform(140, 190, 100),
    'apellembab' : np.random.uniform(75, 85, 100),
    'jerukph' : np.random.uniform(5, 8, 100),
    'jeruksuhu' : np.random.uniform(20, 24, 100),
    'jerukhujan' : np.random.uniform(125, 208, 100),
    'jeruklembab' : np.random.uniform(50, 60, 100),
    'pepayaph' : np.random.uniform(6, 7, 100),
    'pepayasuhu' : np.random.uniform(25, 30, 100),
    'pepayahujan' : np.random.uniform(100, 166, 100),
    'pepayalembab' : np.random.uniform(70, 80, 100)


}

df3 = pd.DataFrame(data)
df3
# Out:
#     jagungsuhu  jagunghujan  jagunglembab  pisangph  pisangsuhu  pisanghujan  \
# 0    28.083570   105.328417     83.319892  7.441155   22.975257   152.989997
# 1    29.021236   137.218117     81.782306  7.000581   25.920350   165.861202
# 2    30.325869   147.441530     80.099920  6.698489   22.809898   172.868517
# 3    29.101191   115.420269     81.026569  7.009347   27.790753   153.686328
# 4    28.737489   100.192003     84.387730  7.467269   23.861483   162.177297
# ..         ...          ...           ...       ...         ...          ...
# 95   28.876664   144.622000     83.582140  7.361613   23.116176   144.545149
# 96   30.966851   134.039172     83.397747  7.061285   22.939326   143.455435
# 97   28.620201   133.425989     80.316265  7.280592   22.561151   149.582182
# 98   31.638349   155.437794     84.660428  7.499847   23.436459   169.068602
# 99   29.100986   137.213730     88.240772  7.278254   22.623841   163.320430
#
# ...

# %%
df3.to_csv('D:\\Kuliah\\Dataset\\datablitar\\hujan.csv')

# %%
# random_decimal_array = np.random.uniform(0, 10, 5)  # Generate 5 random numbers
# print(random_decimal_array)
# Out:
# [7.92232817 2.05668526 8.15449974 5.96780693 5.31283948]
